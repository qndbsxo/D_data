# %% [markdown]
# #### 08_23 00:24:42

# %%
from IPython.display import Image

# %% [markdown]
# # Python Basic : 그래도 중요한 것은 Python 이다
# 파이썬 기초 문법 중요,<br>
# 실제로 나중에 다른 라이브러리 사용법 익힌다 하더라고, <br>
# 결국 막히게 되는 대부분의 경우는 Python 기초 문법 부분입니다

# %% [markdown]
# #### 조건문, 반복문, 파이썬 데이터 타입들..

# %% [markdown]
# # Python Advanced
#
# - lambda
# - lambda operator => map, filter, reduce   <-- lambda 랑 같이 사용하는 함수들. 이들만 사용해도 애지간한 수치연산이 매우 간단하게 이루어짐
# - 특히 reduce 는 N => 1(Value, List, Dict)
# - List Comprehension ( +Dict Comprehension )
# - Class ... object

# %% [markdown]
# ### 깊이있는 파이썬 추천서
# - Learn Python the Hard Way (번역)<br>
# - Hackers Guide to Python (번역 - 실전 파이썬 프로그래밍)    <-- 요게 좀더 어려운 책

# %%
Image('https://images-na.ssl-images-amazon.com/images/I/516A35U3A6L._AC_US218_.jpg')

# %%
Image('https://images-na.ssl-images-amazon.com/images/I/51W-ijSelFL._AC_US218_.jpg')

# %% [markdown]
# # 데이터 크롤링

# %%
# - 스크래핑, 크롤링, 파싱( HTML, JSON, XML ...)

# 1. 정적인 사이트
# 2. 동적인 사이트 ( AJAX 기술로 데이터가 넘어옴.. 직방, 요기요 )
# ---------------------------
# 3. 파이썬을 가지고 웹 브라우저를 동작시키는 방법 (selenium)
#    Python ... selenium ... Chrome API ... Chrome
#    Python ... selenium ... Firefox API ... Firefox

# %% [markdown]
# # Numpy
#
# numpy.ndarray => pd.Series, pd.DataFrame

# %%
# 머신러닝을 하다보면, Pandas 보다는 Numpy 를 훨~씬 더 많이 사용하게 될 겁니다
# n차원 행렬 데이터 이니..

# list 와는 다르다!

# %% [markdown]
# # Pandas
#
# - pd.Series
# - pd.DataFrame
#
# - Database!  <-- 엑셀보다는 DB 를 더 많이 다루게 된다.
#
# - 각각에 대해서 데이터 추가/삭제/변경 ,  인덱스 다루기 등

# %% [markdown]
# # split-apply-combine 전략
#
# 1. split
#     - groupby, get_group
#
# 2. apply
#     - 1. agg(N=>1): Series => Value
#     - 2. transform(N=>N)  DataFrame => DataFrame, Series => Series
#     - 3. apply(N=>M, N, 1) DataFrame => DF, Series, Value
#     - 4. filter(N => N')  DataFrame => DF, Series => Series
#
# 3. combine

# %% [markdown]
# # Matplotlib + seaborn
#
# 1. matplotlib.pyplot (plt) ... plt.title()
# 2. Figure, Subplot(ax)  ... ax.set_title()
#
# 3. pd.Series, pd.DataFrame .plot() => Figure, Subplot

# %% [markdown]
# #### numpy. pandas 추천서
# - 파이썬 라이브러리를 활용한 데이터 분석
# - 밑바닥부터 시작하는  데이터 과학  데이터 분석을 위한 파이썬 프로그래밍과 수학, 통계 기초

# %%
# - 저자가 Pandas 만드신 분임,  자세하고 원리, 설명 충실 
Image('http://image.yes24.com/momo/TopCate1232/MidCate001/123104763.jpg', width=200)

# %%
# 위 책보다는 난이도가 있다.
# 그러나, 통계적인 베이스가 있다.
Image('http://image.yes24.com/momo/TopCate1232/MidCate001/123105899.jpg', width=200)

# %% [markdown]
# ## 그 다음부터는 여러분이 나아갈 방향에 따라 다릅니다

# %%
# https://github.com/dobestan
# 업무 자동화, 데이터분석

# %% [markdown]
# #### 08_23 끝
